# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
# 载入数据
mnist = input_data.read_data_sets("./MNIST_Data", one_hot=True)

# 每个批次的大小
batch_size = 100

# 计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

# 定义两个placeholder
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])
keep_drop = tf.placeholder(tf.float32)

# 创建神经网络
W1 = tf.Variable(tf.truncated_normal([784, 2000], stddev=0.1))
b1 = tf.Variable(tf.zeros([2000]) + 0.1)
L1 = tf.nn.tanh(tf.matmul(x, W1) + b1)
L1_drop = tf.nn.dropout(L1, keep_drop)


W2 = tf.Variable(tf.truncated_normal([2000, 1000], stddev=0.1))
b2 = tf.Variable(tf.zeros([1000]) + 0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop, W2) + b2)
L2_drop = tf.nn.dropout(L2, keep_drop)

W3 = tf.Variable(tf.truncated_normal([1000, 10], stddev=0.1))
b3 = tf.Variable(tf.zeros([10]) + 0.1)
# L3 = tf.nn.tanh(tf.matmul(L2_drop, W3) + b3)
# L3_drop = tf.nn.dropout(L3, keep_drop)

prediction = tf.nn.softmax(tf.matmul(L2_drop, W3) + b3)

# 二次代价函数
# loss = tf.reduce_mean(tf.square(y - prediction))
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=prediction))
# 梯度下降法
train = tf.train.GradientDescentOptimizer(0.9).minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

# 预测结果
correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))

# 求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

epochs = 20


with tf.Session() as sess:
    sess.run(init)
    for epoch in range(epochs):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train, feed_dict={x: batch_xs, y: batch_ys, keep_drop: 1.0})
        acc_train = sess.run(accuracy, feed_dict={x: mnist.train.images, y: mnist.train.labels, keep_drop: 1.0})
        acc_test = sess.run(accuracy, feed_dict={x: mnist.test.images, y: mnist.test.labels, keep_drop: 1.0})
        print("Epoch {} - Train accuracy: {} - Test accuracy: {}".format(epoch, acc_train, acc_test))
# Out:
# Extracting ./MNIST_Data/train-images-idx3-ubyte.gz
# Extracting ./MNIST_Data/train-labels-idx1-ubyte.gz
# Extracting ./MNIST_Data/t10k-images-idx3-ubyte.gz
# Extracting ./MNIST_Data/t10k-labels-idx1-ubyte.gz
# Epoch 0 - Train accuracy: 0.8536182045936584 - Test accuracy: 0.848800003528595
# Epoch 1 - Train accuracy: 0.8736181855201721 - Test accuracy: 0.8669999837875366
# Epoch 2 - Train accuracy: 0.8800908923149109 - Test accuracy: 0.8712000250816345
# Epoch 3 - Train accuracy: 0.8861818313598633 - Test accuracy: 0.876800000667572
# Epoch 4 - Train accuracy: 0.9818545579910278 - Test accuracy: 0.9674999713897705
# Epoch 5 - Train accuracy: 0.9858545660972595 - Test accuracy: 0.9707000255584717
# Epoch 6 - Train accuracy: 0.9903091192245483 - Test accuracy: 0.9750999808311462
# Epoch 7 - Train accuracy: 0.9881636500358582 - Test accuracy: 0.972000002861023
# Epoch 8 - Train accuracy: 0.9929272532463074 - Test accuracy: 0.9785000085830688
# ...

# %%
# 载入数据
mnist = input_data.read_data_sets("./MNIST_Data", one_hot=True)

# 每个批次的大小
batch_size = 100

# 计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

# 定义两个placeholder
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])
keep_drop = tf.placeholder(tf.float32)

# 创建神经网络
W1 = tf.Variable(tf.truncated_normal([784, 2000], stddev=0.1))
b1 = tf.Variable(tf.zeros([2000]) + 0.1)
L1 = tf.nn.tanh(tf.matmul(x, W1) + b1)
L1_drop = tf.nn.dropout(L1, keep_drop)


W2 = tf.Variable(tf.truncated_normal([2000, 1000], stddev=0.1))
b2 = tf.Variable(tf.zeros([1000]) + 0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop, W2) + b2)
L2_drop = tf.nn.dropout(L2, keep_drop)

W3 = tf.Variable(tf.truncated_normal([1000, 10], stddev=0.1))
b3 = tf.Variable(tf.zeros([10]) + 0.1)
# L3 = tf.nn.tanh(tf.matmul(L2_drop, W3) + b3)
# L3_drop = tf.nn.dropout(L3, keep_drop)

prediction = tf.nn.softmax(tf.matmul(L2_drop, W3) + b3)

# 二次代价函数
# loss = tf.reduce_mean(tf.square(y - prediction))
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=prediction))
# 梯度下降法
train = tf.train.GradientDescentOptimizer(0.9).minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

# 预测结果
correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))

# 求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

epochs = 20


with tf.Session() as sess:
    sess.run(init)
    for epoch in range(epochs):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train, feed_dict={x: batch_xs, y: batch_ys, keep_drop: 0.7})
        acc_train = sess.run(accuracy, feed_dict={x: mnist.train.images, y: mnist.train.labels, keep_drop: 1.0})
        acc_test = sess.run(accuracy, feed_dict={x: mnist.test.images, y: mnist.test.labels, keep_drop: 1.0})
        print("Epoch {} - Train accuracy: {} - Test accuracy: {}".format(epoch, acc_train, acc_test))
# Out:
# Extracting ./MNIST_Data/train-images-idx3-ubyte.gz
# Extracting ./MNIST_Data/train-labels-idx1-ubyte.gz
# Extracting ./MNIST_Data/t10k-images-idx3-ubyte.gz
# Extracting ./MNIST_Data/t10k-labels-idx1-ubyte.gz
# Epoch 0 - Train accuracy: 0.9271273016929626 - Test accuracy: 0.925599992275238
# Epoch 1 - Train accuracy: 0.9390909075737 - Test accuracy: 0.9420999884605408
# Epoch 2 - Train accuracy: 0.9504181742668152 - Test accuracy: 0.9455000162124634
# Epoch 3 - Train accuracy: 0.956745445728302 - Test accuracy: 0.953499972820282
# Epoch 4 - Train accuracy: 0.9631636142730713 - Test accuracy: 0.9585000276565552
# Epoch 5 - Train accuracy: 0.9630181789398193 - Test accuracy: 0.9596999883651733
# Epoch 6 - Train accuracy: 0.9679454565048218 - Test accuracy: 0.9643999934196472
# Epoch 7 - Train accuracy: 0.9664545655250549 - Test accuracy: 0.9635999798774719
# Epoch 8 - Train accuracy: 0.9695454835891724 - Test accuracy: 0.9643999934196472
# ...
